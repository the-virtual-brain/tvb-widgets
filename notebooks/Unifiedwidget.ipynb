# %%
from tvbwidgets.ui.Unified_widget.Unified_widget import LargeScaleConnectivityWidget
from tvb.datatypes.connectivity import Connectivity

conn = Connectivity().from_file()  
conn.configure()

wid = LargeScaleConnectivityWidget(conn)
wid.display()
