# %%
from tvb.datatypes.connectivity import Connectivity
from tvbwidgets.ui.bct.bct_metrics_widget import BCTMetricsProjectionWidget

conn = Connectivity.from_file()
conn.configure()

wid = BCTMetricsProjectionWidget(conn)
wid.display()
