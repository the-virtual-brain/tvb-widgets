# %% [markdown]
# ## TVB Dicom Widget

# %% [markdown]
# ---

# %% [markdown]
# ### This notebook is dedicated to showcasing the Dicom widget
# #### *Note: This widget accepts 2 types of data: `numpy.ndarray` and `tvb.datatypes.structural.StructuralMRI`.*

# %%
import numpy as np
from tvbwidgets.api import DicomWidget
from tvb.adapters.uploaders.nifti.parser import NIFTIParser

from bokeh.io import output_notebook
output_notebook() # tell Bokeh to display the widget inside the notebook
# Out:
# 19-03-2026 12:40:57 - INFO - tvbwidgets - Version: 2.3.2
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\tvb\basic\neotraits\_attr.py", line 114, in _post_bind_validate
#     hash(self.default)
# TypeError: unhashable type: 'dict'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\logging\handlers.py", line 74, in emit
#     self.doRollover()
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\logging\handlers.py", line 435, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\logging\handlers.py", line 115, in rotate
#     os.rename(source, dest)
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'C:\\Users\\deept\\.tvb-temp\\logs\\library.log' -> 'C:\\Users\\deept\\.tvb-temp\\logs\\library.log.2026-03-18'
# Call stack:
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\asyncio\base_events.py", line 603, in run_forever
#     self._run_once()
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\asyncio\base_events.py", line 1909, in _run_once
#     handle._run()
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\utils.py", line 71, in preserve_context
#     return await f(*args, **kwargs)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\kernelbase.py", line 621, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\kernelbase.py", line 478, in dispatch_shell
#     await result
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\ipkernel.py", line 372, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\kernelbase.py", line 834, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\ipkernel.py", line 464, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\IPython\core\interactiveshell.py", line 3006, in run_cell
#     result = self._run_cell(
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\IPython\core\interactiveshell.py", line 3061, in _run_cell
#     result = runner(coro)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\IPython\core\interactiveshell.py", line 3266, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\IPython\core\interactiveshell.py", line 3445, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\IPython\core\interactiveshell.py", line 3505, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\deept\AppData\Local\Temp\ipykernel_3768\3426674604.py", line 2, in <module>
#     from tvbwidgets.api import DicomWidget
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "C:\Users\deept\tvb-widgets\tvbwidgets\api.py", line 12, in <module>
#     from .ui.phase_plane_widget import PhasePlaneWidget
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "C:\Users\deept\tvb-widgets\tvbwidgets\ui\phase_plane_widget.py", line 16, in <module>
#     from tvb.simulator.lab import integrators
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\tvb\simulator\lab.py", line 55, in <module>
#     from tvb.simulator import (simulator, models, coupling, integrators, monitors, noise)
#   File "<frozen importlib._bootstrap>", line 1078, in _handle_fromlist
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\tvb\simulator\simulator.py", line 45, in <module>
#     from tvb.simulator import models, integrators, monitors, coupling
#   File "<frozen importlib._bootstrap>", line 1078, in _handle_fromlist
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\tvb\simulator\monitors.py", line 56, in <module>
#     from tvb.datatypes.time_series import (TimeSeries, TimeSeriesRegion, TimeSeriesEEG, TimeSeriesMEG, TimeSeriesSEEG,
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\tvb\datatypes\time_series.py", line 42, in <module>
#     class TimeSeries(HasTraits):
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\tvb\basic\neotraits\_declarative_base.py", line 228, in __new__
#     v._post_bind_validate()
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\tvb\basic\neotraits\_attr.py", line 116, in _post_bind_validate
#     log.warning('Field seems mutable and has a default value. '
# Message: "Field seems mutable and has a default value. Consider using a lambda as a value factory \n   attribute tvb.datatypes.time_series.TimeSeries.labels_dimensions = Attr(field_type=<class 'dict'>, default={}, required=True)"
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\tvb\basic\neotraits\_attr.py", line 114, in _post_bind_validate
#     hash(self.default)
# TypeError: unhashable type: 'dict'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\logging\handlers.py", line 74, in emit
#     self.doRollover()
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\logging\handlers.py", line 435, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\logging\handlers.py", line 115, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\deept\\.tvb-temp\\logs\\library.log' -> 'C:\\Users\\deept\\.tvb-temp\\logs\\library.log.2026-03-18'
# Call stack:
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\asyncio\base_events.py", line 603, in run_forever
#     self._run_once()
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\asyncio\base_events.py", line 1909, in _run_once
#     handle._run()
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\utils.py", line 71, in preserve_context
#     return await f(*args, **kwargs)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\kernelbase.py", line 621, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\kernelbase.py", line 478, in dispatch_shell
#     await result
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\ipkernel.py", line 372, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\kernelbase.py", line 834, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\ipkernel.py", line 464, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\IPython\core\interactiveshell.py", line 3006, in run_cell
#     result = self._run_cell(
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\IPython\core\interactiveshell.py", line 3061, in _run_cell
#     result = runner(coro)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\IPython\core\interactiveshell.py", line 3266, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\IPython\core\interactiveshell.py", line 3445, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\IPython\core\interactiveshell.py", line 3505, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\deept\AppData\Local\Temp\ipykernel_3768\3426674604.py", line 2, in <module>
#     from tvbwidgets.api import DicomWidget
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "C:\Users\deept\tvb-widgets\tvbwidgets\api.py", line 12, in <module>
#     from .ui.phase_plane_widget import PhasePlaneWidget
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "C:\Users\deept\tvb-widgets\tvbwidgets\ui\phase_plane_widget.py", line 16, in <module>
#     from tvb.simulator.lab import integrators
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\tvb\simulator\lab.py", line 55, in <module>
#     from tvb.simulator import (simulator, models, coupling, integrators, monitors, noise)
#   File "<frozen importlib._bootstrap>", line 1078, in _handle_fromlist
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\tvb\simulator\simulator.py", line 45, in <module>
#     from tvb.simulator import models, integrators, monitors, coupling
#   File "<frozen importlib._bootstrap>", line 1078, in _handle_fromlist
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\tvb\simulator\monitors.py", line 60, in <module>
#     import tvb.datatypes.projections as projections_module
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\tvb\datatypes\projections.py", line 43, in <module>
#     class ProjectionMatrix(HasTraits):
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\tvb\basic\neotraits\_declarative_base.py", line 228, in __new__
#     v._post_bind_validate()
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\tvb\basic\neotraits\_attr.py", line 116, in _post_bind_validate
#     log.warning('Field seems mutable and has a default value. '
# Message: "Field seems mutable and has a default value. Consider using a lambda as a value factory \n   attribute tvb.datatypes.projections.ProjectionMatrix.conductances = Attr(field_type=<class 'dict'>, default={'air': 0.0, 'skin': 1.0, 'skull': 0.01, 'brain': 1.0}, required=False)"
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\logging\handlers.py", line 74, in emit
#     self.doRollover()
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\logging\handlers.py", line 435, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\logging\handlers.py", line 115, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\deept\\.tvb-temp\\logs\\library.log' -> 'C:\\Users\\deept\\.tvb-temp\\logs\\library.log.2026-03-18'
# Call stack:
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\asyncio\base_events.py", line 603, in run_forever
#     self._run_once()
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\asyncio\base_events.py", line 1909, in _run_once
#     handle._run()
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\utils.py", line 71, in preserve_context
#     return await f(*args, **kwargs)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\kernelbase.py", line 621, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\kernelbase.py", line 478, in dispatch_shell
#     await result
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\ipkernel.py", line 372, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\kernelbase.py", line 834, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\ipkernel.py", line 464, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\IPython\core\interactiveshell.py", line 3006, in run_cell
#     result = self._run_cell(
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\IPython\core\interactiveshell.py", line 3061, in _run_cell
#     result = runner(coro)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\IPython\core\interactiveshell.py", line 3266, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\IPython\core\interactiveshell.py", line 3445, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\IPython\core\interactiveshell.py", line 3505, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\deept\AppData\Local\Temp\ipykernel_3768\3426674604.py", line 2, in <module>
#     from tvbwidgets.api import DicomWidget
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "C:\Users\deept\tvb-widgets\tvbwidgets\api.py", line 12, in <module>
#     from .ui.phase_plane_widget import PhasePlaneWidget
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "C:\Users\deept\tvb-widgets\tvbwidgets\ui\phase_plane_widget.py", line 16, in <module>
#     from tvb.simulator.lab import integrators
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\tvb\simulator\lab.py", line 55, in <module>
#     from tvb.simulator import (simulator, models, coupling, integrators, monitors, noise)
#   File "<frozen importlib._bootstrap>", line 1078, in _handle_fromlist
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\tvb\simulator\simulator.py", line 45, in <module>
#     from tvb.simulator import models, integrators, monitors, coupling
#   File "<frozen importlib._bootstrap>", line 1078, in _handle_fromlist
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\tvb\simulator\coupling.py", line 227, in <module>
#     class HyperbolicTangent(SparseCoupling):
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\tvb\basic\neotraits\_declarative_base.py", line 228, in __new__
#     v._post_bind_validate()
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\tvb\basic\neotraits\_attr.py", line 491, in _post_bind_validate
#     log.warning('{} \n   attribute  {}'.format(msg, self))
# Message: "default contains values out of the declared domain. Ex 1.0 \n   attribute  tvb.simulator.coupling.HyperbolicTangent.b = NArray(label=':math:`b`', dtype=float64, default=array([1.]), dim_names=(), ndim=None, required=True)"
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\logging\handlers.py", line 74, in emit
#     self.doRollover()
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\logging\handlers.py", line 435, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\logging\handlers.py", line 115, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\deept\\.tvb-temp\\logs\\library.log' -> 'C:\\Users\\deept\\.tvb-temp\\logs\\library.log.2026-03-18'
# Call stack:
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\asyncio\base_events.py", line 603, in run_forever
#     self._run_once()
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\asyncio\base_events.py", line 1909, in _run_once
#     handle._run()
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\utils.py", line 71, in preserve_context
#     return await f(*args, **kwargs)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\kernelbase.py", line 621, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\kernelbase.py", line 478, in dispatch_shell
#     await result
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\ipkernel.py", line 372, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\kernelbase.py", line 834, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\ipkernel.py", line 464, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\IPython\core\interactiveshell.py", line 3006, in run_cell
#     result = self._run_cell(
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\IPython\core\interactiveshell.py", line 3061, in _run_cell
#     result = runner(coro)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\IPython\core\interactiveshell.py", line 3266, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\IPython\core\interactiveshell.py", line 3445, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\IPython\core\interactiveshell.py", line 3505, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\deept\AppData\Local\Temp\ipykernel_3768\3426674604.py", line 2, in <module>
#     from tvbwidgets.api import DicomWidget
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "C:\Users\deept\tvb-widgets\tvbwidgets\api.py", line 12, in <module>
#     from .ui.phase_plane_widget import PhasePlaneWidget
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "C:\Users\deept\tvb-widgets\tvbwidgets\ui\phase_plane_widget.py", line 16, in <module>
#     from tvb.simulator.lab import integrators
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\tvb\simulator\lab.py", line 55, in <module>
#     from tvb.simulator import (simulator, models, coupling, integrators, monitors, noise)
#   File "<frozen importlib._bootstrap>", line 1078, in _handle_fromlist
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\tvb\simulator\simulator.py", line 45, in <module>
#     from tvb.simulator import models, integrators, monitors, coupling
#   File "<frozen importlib._bootstrap>", line 1078, in _handle_fromlist
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\tvb\simulator\coupling.py", line 489, in <module>
#     class Kuramoto(SparseCoupling):
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\tvb\basic\neotraits\_declarative_base.py", line 228, in __new__
#     v._post_bind_validate()
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\tvb\basic\neotraits\_attr.py", line 491, in _post_bind_validate
#     log.warning('{} \n   attribute  {}'.format(msg, self))
# Message: "default contains values out of the declared domain. Ex 1.0 \n   attribute  tvb.simulator.coupling.Kuramoto.a = NArray(label=':math:`a`', dtype=float64, default=array([1.]), dim_names=(), ndim=None, required=True)"
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\logging\handlers.py", line 74, in emit
#     self.doRollover()
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\logging\handlers.py", line 435, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\logging\handlers.py", line 115, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\deept\\.tvb-temp\\logs\\library.log' -> 'C:\\Users\\deept\\.tvb-temp\\logs\\library.log.2026-03-18'
# Call stack:
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\asyncio\base_events.py", line 603, in run_forever
#     self._run_once()
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\asyncio\base_events.py", line 1909, in _run_once
#     handle._run()
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\utils.py", line 71, in preserve_context
#     return await f(*args, **kwargs)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\kernelbase.py", line 621, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\kernelbase.py", line 478, in dispatch_shell
#     await result
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\ipkernel.py", line 372, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\kernelbase.py", line 834, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\ipkernel.py", line 464, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\IPython\core\interactiveshell.py", line 3006, in run_cell
#     result = self._run_cell(
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\IPython\core\interactiveshell.py", line 3061, in _run_cell
#     result = runner(coro)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\IPython\core\interactiveshell.py", line 3266, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\IPython\core\interactiveshell.py", line 3445, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\IPython\core\interactiveshell.py", line 3505, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\deept\AppData\Local\Temp\ipykernel_3768\3426674604.py", line 2, in <module>
#     from tvbwidgets.api import DicomWidget
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "C:\Users\deept\tvb-widgets\tvbwidgets\api.py", line 12, in <module>
#     from .ui.phase_plane_widget import PhasePlaneWidget
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "C:\Users\deept\tvb-widgets\tvbwidgets\ui\phase_plane_widget.py", line 16, in <module>
#     from tvb.simulator.lab import integrators
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\tvb\simulator\lab.py", line 55, in <module>
#     from tvb.simulator import (simulator, models, coupling, integrators, monitors, noise)
#   File "<frozen importlib._bootstrap>", line 1078, in _handle_fromlist
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\tvb\simulator\simulator.py", line 55, in <module>
#     class Simulator(HasTraits):
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\tvb\simulator\simulator.py", line 113, in Simulator
#     default=models.Generic2dOscillator,
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\tvb\simulator\models\__init__.py", line 142, in do_import
#     model_module = importlib.import_module(module_name)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\importlib\__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\tvb\simulator\models\oscillator.py", line 39, in <module>
#     class Generic2dOscillator(ModelNumbaDfun):
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\tvb\basic\neotraits\_declarative_base.py", line 228, in __new__
#     v._post_bind_validate()
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\tvb\basic\neotraits\_attr.py", line 491, in _post_bind_validate
#     log.warning('{} \n   attribute  {}'.format(msg, self))
# Message: "default contains values out of the declared domain. Ex 1.0 \n   attribute  tvb.simulator.models.oscillator.Generic2dOscillator.gamma = NArray(label=':math:`\\\\gamma`', dtype=float64, default=array([1.]), dim_names=(), ndim=None, required=True)"
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\tvb\basic\neotraits\_attr.py", line 114, in _post_bind_validate
#     hash(self.default)
# TypeError: unhashable type: 'dict'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\logging\handlers.py", line 74, in emit
#     self.doRollover()
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\logging\handlers.py", line 435, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\logging\handlers.py", line 115, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\deept\\.tvb-temp\\logs\\library.log' -> 'C:\\Users\\deept\\.tvb-temp\\logs\\library.log.2026-03-18'
# Call stack:
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\asyncio\base_events.py", line 603, in run_forever
#     self._run_once()
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\asyncio\base_events.py", line 1909, in _run_once
#     handle._run()
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\utils.py", line 71, in preserve_context
#     return await f(*args, **kwargs)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\kernelbase.py", line 621, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\kernelbase.py", line 478, in dispatch_shell
#     await result
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\ipkernel.py", line 372, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\kernelbase.py", line 834, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\ipkernel.py", line 464, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\IPython\core\interactiveshell.py", line 3006, in run_cell
#     result = self._run_cell(
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\IPython\core\interactiveshell.py", line 3061, in _run_cell
#     result = runner(coro)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\IPython\core\interactiveshell.py", line 3266, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\IPython\core\interactiveshell.py", line 3445, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\IPython\core\interactiveshell.py", line 3505, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\deept\AppData\Local\Temp\ipykernel_3768\3426674604.py", line 2, in <module>
#     from tvbwidgets.api import DicomWidget
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "C:\Users\deept\tvb-widgets\tvbwidgets\api.py", line 12, in <module>
#     from .ui.phase_plane_widget import PhasePlaneWidget
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "C:\Users\deept\tvb-widgets\tvbwidgets\ui\phase_plane_widget.py", line 16, in <module>
#     from tvb.simulator.lab import integrators
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
# ...
#     self._run_once()
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\asyncio\base_events.py", line 1909, in _run_once
#     handle._run()
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\utils.py", line 71, in preserve_context
#     return await f(*args, **kwargs)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\kernelbase.py", line 621, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\kernelbase.py", line 478, in dispatch_shell
#     await result
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\ipkernel.py", line 372, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\kernelbase.py", line 834, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\ipkernel.py", line 464, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\IPython\core\interactiveshell.py", line 3006, in run_cell
#     result = self._run_cell(
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\IPython\core\interactiveshell.py", line 3061, in _run_cell
#     result = runner(coro)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\IPython\core\interactiveshell.py", line 3266, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\IPython\core\interactiveshell.py", line 3445, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\IPython\core\interactiveshell.py", line 3505, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\deept\AppData\Local\Temp\ipykernel_3768\3426674604.py", line 2, in <module>
#     from tvbwidgets.api import DicomWidget
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "C:\Users\deept\tvb-widgets\tvbwidgets\api.py", line 12, in <module>
#     from .ui.phase_plane_widget import PhasePlaneWidget
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "C:\Users\deept\tvb-widgets\tvbwidgets\ui\phase_plane_widget.py", line 16, in <module>
#     from tvb.simulator.lab import integrators
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\tvb\simulator\lab.py", line 55, in <module>
#     from tvb.simulator import (simulator, models, coupling, integrators, monitors, noise)
#   File "<frozen importlib._bootstrap>", line 1078, in _handle_fromlist
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\tvb\simulator\simulator.py", line 55, in <module>
#     class Simulator(HasTraits):
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\tvb\simulator\simulator.py", line 113, in Simulator
#     default=models.Generic2dOscillator,
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\tvb\simulator\models\__init__.py", line 142, in do_import
#     model_module = importlib.import_module(module_name)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\importlib\__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\tvb\simulator\models\oscillator.py", line 493, in <module>
#     class SupHopf(ModelNumbaDfun):
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\tvb\basic\neotraits\_declarative_base.py", line 228, in __new__
#     v._post_bind_validate()
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\tvb\basic\neotraits\_attr.py", line 116, in _post_bind_validate
#     log.warning('Field seems mutable and has a default value. '
# Message: "Field seems mutable and has a default value. Consider using a lambda as a value factory \n   attribute tvb.simulator.models.oscillator.SupHopf.state_variable_range = Final(field_type=<class 'dict'>, default={'x': array([-5.,  5.]), 'y': array([-5.,  5.])}, required=True)"
# Arguments: ()
# Using matplotlib as 2D backend.
# 2026-03-19 12:41:24,550 - INFO - tvb.storage.h5.encryption.data_encryption_handler - Cannot import syncrypto library.
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\tvb\storage\h5\encryption\data_encryption_handler.py", line 49, in <module>
#     from syncrypto import Crypto, Syncrypto
# ModuleNotFoundError: No module named 'syncrypto'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\logging\handlers.py", line 74, in emit
#     self.doRollover()
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\logging\handlers.py", line 435, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\logging\handlers.py", line 115, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\deept\\.tvb-temp\\logs\\library.log' -> 'C:\\Users\\deept\\.tvb-temp\\logs\\library.log.2026-03-18'
# Call stack:
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\asyncio\base_events.py", line 603, in run_forever
#     self._run_once()
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\asyncio\base_events.py", line 1909, in _run_once
#     handle._run()
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\utils.py", line 71, in preserve_context
#     return await f(*args, **kwargs)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\kernelbase.py", line 621, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\kernelbase.py", line 478, in dispatch_shell
#     await result
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\ipkernel.py", line 372, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\kernelbase.py", line 834, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\ipkernel.py", line 464, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\IPython\core\interactiveshell.py", line 3006, in run_cell
#     result = self._run_cell(
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\IPython\core\interactiveshell.py", line 3061, in _run_cell
#     result = runner(coro)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\IPython\core\interactiveshell.py", line 3266, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\IPython\core\interactiveshell.py", line 3445, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\IPython\core\interactiveshell.py", line 3505, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\deept\AppData\Local\Temp\ipykernel_3768\3426674604.py", line 2, in <module>
#     from tvbwidgets.api import DicomWidget
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "C:\Users\deept\tvb-widgets\tvbwidgets\api.py", line 19, in <module>
#     from .ui.pse_widget import PSEWidget
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "C:\Users\deept\tvb-widgets\tvbwidgets\ui\pse_widget.py", line 13, in <module>
#     from tvbwidgets.core.pse.pse_data import PSEData, PSEStorage
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "C:\Users\deept\tvb-widgets\tvbwidgets\core\pse\pse_data.py", line 9, in <module>
#     from tvb.core.neotraits.h5 import H5File, DataSet, Scalar, Json
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\tvb\core\neotraits\h5.py", line 31, in <module>
#     from ._h5core import H5File, ViewModelH5
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\tvb\core\neotraits\_h5core.py", line 43, in <module>
#     from tvb.storage.storage_interface import StorageInterface
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\tvb\storage\storage_interface.py", line 39, in <module>
#     from tvb.storage.h5.encryption.data_encryption_handler import FoldersQueueConsumer, encryption_handler
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\tvb\storage\h5\encryption\data_encryption_handler.py", line 51, in <module>
#     LOGGER.info("Cannot import syncrypto library.")
# Message: 'Cannot import syncrypto library.'
# Arguments: ()
# 19-03-2026 12:41:25 - INFO - tvbwidgets.core.pse.parameters - ImportError: Dask dependency is not included, so this functionality won't be available
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="c080a471-91b2-4bfe-bf4d-643fd6326b6d">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ### Read input data

# %% [markdown]
# #### Either read and parse the data using the NIFTI Parser from TVB
# (Uncomment the 2 lines and replace `path_to_nii_file` with the correct path to your file)

# %%
# parser = NIFTIParser(data_file='path_to_nii_file')
# data = parser.parse()

# %% [markdown]
# #### Or use an existent numpy.ndarray/ TVB StructuralMRI object

# %%
# create demo array just to demonstrate the usage of the API
rng = np.random.default_rng()
data = rng.random((255,255,255))

# %% [markdown]
# ### Display the widget

# %%
widget = DicomWidget(data)

# %%
widget.show_widget()
# Out:
# <script id="b103051b-b9ec-4dc3-8f71-a97318e6b4ed">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:50907/autoload.js?bokeh-autoload-element=b103051b-b9ec-4dc3-8f71-a97318e6b4ed&bokeh-absolute-url=http://localhost:50907&resources=none", true);
#     xhr.withCredentials = false;
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>
