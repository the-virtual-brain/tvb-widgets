# %% [markdown]
# # Demonstrate Parameter Search Exploration (PSE) Widgets: Launch and View

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib widget

# %%
from tvbwidgets.api import PSELauncher, PSEWidget, HPCConfig
from tvb.simulator.lab import *
from tvb.simulator.models import Epileptor
from tvb.simulator.integrators import HeunStochastic
# Out:
# 19-03-2026 12:55:27 - INFO - tvbwidgets - Version: 2.3.2
# Using matplotlib as 2D backend.
# 2026-03-19 12:55:33,188 - INFO - tvb.storage.h5.encryption.data_encryption_handler - Cannot import syncrypto library.
# 19-03-2026 12:55:33 - INFO - tvbwidgets.core.pse.parameters - ImportError: Dask dependency is not included, so this functionality won't be available

# %% [markdown]
# ## Launch a PSE
# ### Bellow we prepare an optional configuration for HPC runs:

# %%
os.environ['CLB_AUTH'] = 'PUT YOUR EBRAINS TOKEN HERE IF YOU WANT HPC RUNS'

from pyunicore.helpers.jobs import Resources
res = Resources(cpus_per_node=4)

hpc_config = HPCConfig(site="JUSUF", project="icei-hbp-2021-0007", 
                       # !! Pay attention to env name and dir you might need to change if in conflict on the SAME project with another coleague of yours!!
                       env_dir="tvb_widget", env_name="venv_tvb", 
                       n_threads=None, resources=res)
res
# Out:
# Resources(runtime=None, queue=None, nodes=None, cpus=None, cpus_per_node=4, memory=None, reservation=None, node_constraints=None, qos=None)

# %%
# Optionally: preare multiple structural connectivities, in case we want to range over them.
conn_66 = connectivity.Connectivity.from_file("connectivity_66.zip")
conn_68 = connectivity.Connectivity.from_file("connectivity_68.zip")
conn_76 = connectivity.Connectivity.from_file()

sim = simulator.Simulator(connectivity = connectivity.Connectivity.from_file())
sim.model = Epileptor()

# when hpc_config param is missing the "HPC Launch" button will be disabled, and only "Local launch" will be possible
# launch = PSELauncher(sim, [conn_66, conn_68, conn_76], None)

launch = PSELauncher(sim, [conn_66, conn_68, conn_76], hpc_config)
# Out:
# 2026-03-19 12:55:35,502 - WARNING - tvb.basic.readers - File 'average_orientations' not found in ZIP.
# 2026-03-19 12:55:35,503 - WARNING - tvb.basic.readers - File 'cortical' not found in ZIP.
# 2026-03-19 12:55:35,504 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2026-03-19 12:55:35,506 - WARNING - tvb.basic.readers - File 'areas' not found in ZIP.
# 2026-03-19 12:55:35,542 - WARNING - tvb.basic.readers - File 'cortical' not found in ZIP.
# 2026-03-19 12:55:35,544 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2026-03-19 12:55:35,544 - WARNING - tvb.basic.readers - File 'areas' not found in ZIP.
# 2026-03-19 12:55:35,556 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2026-03-19 12:55:35,568 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# VBox(children=(HTML(value="<font color='navyblue' size='4'>PSE Launcher</font>", layout=Layout(margin='0px 0px…

# %% [markdown]
# ## View PSE Results
# ### ! The parts after this point, should be executed only after the PSE was launched and completed execution above

# %%
# file_name  -> resulted from PSELauncher above

import os.path

file_name = "result.h5"

if os.path.exists(file_name):
    pse = PSEWidget(file_name)
else:
    print(f"File {file_name} needs to exist!")
# Out:
# File result.h5 needs to exist!
