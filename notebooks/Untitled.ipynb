# %%
import bct
import numpy as np
from tvb.datatypes.connectivity import Connectivity


connectivity = Connectivity.from_file()


weights = connectivity.weights

result = bct.modularity_dir(connectivity.weights)
print(result)
# Out:
# 2026-03-18 22:53:09,123 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\bct\algorithms\modularity.py:374: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if np.array(dc).shape is not ():
# C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\bct\algorithms\modularity.py:374: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if np.array(dc).shape is not ():
# C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\bct\algorithms\modularity.py:374: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if np.array(dc).shape is not ():
# C:\Users\deept\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\bct\algorithms\modularity.py:374: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if np.array(dc).shape is not ():
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\numpy\_core\fromnumeric.py:3604, in size(a, axis)
#    3603 try:
# -> 3604     return a.size
#    3605 except AttributeError:
#
# AttributeError: 'list' object has no attribute 'size'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 11
#       6 connectivity = Connectivity.from_file()
#       9 weights = connectivity.weights
# ---> 11 result = bct.modularity_dir(connectivity.weights)
#      12 print(result)
#
# File ~\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\bct\algorithms\modularity.py:580, in modularity_dir(A, gamma, kci)
#     578 if kci is None:
#     579     recur(init_mod)
# --> 580     ci = ls2ci(modules)
#     581 else:
#     582     ci = kci
#
# File ~\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\bct\algorithms\modularity.py:60, in ls2ci(ls, zeroindexed)
#      42 def ls2ci(ls, zeroindexed=False):
#      43     '''
#      44     Convert from a 2D python list of modules to a community index vector.
#      45     The list is a pure python list, not requiring numpy.
#    (...)
#      58         community index vector
#      59     '''
# ---> 60     if ls is None or np.size(ls) == 0:
#      61         return ()  # list is empty
#      62     nr_indices = sum(map(len, ls))
#
# File ~\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\numpy\_core\fromnumeric.py:3606, in size(a, axis)
#    3604         return a.size
#    3605     except AttributeError:
# -> 3606         return asarray(a).size
#    3607 else:
#    3608     try:
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2,) + inhomogeneous part.
