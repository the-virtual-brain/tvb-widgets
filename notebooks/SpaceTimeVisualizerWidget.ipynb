# %%
from tvb.datatypes.connectivity import Connectivity
from tvbwidgets.ui.spacetime_widget import SpaceTimeVisualizerWidget
conn = Connectivity.from_file() # defaults to connectivy_76.zip
conn.configure()
# Out:
# 20-06-2024 08:19:32 - DEBUG - tvbwidgets - Package is not fully installed
# 20-06-2024 08:19:32 - DEBUG - tvbwidgets - Version read from the internal package.json file
# 20-06-2024 08:19:32 - INFO - tvbwidgets - Version: 2.0.3
# 2024-06-20 08:19:33,284 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.

# %%
x = SpaceTimeVisualizerWidget(conn)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Dell\anaconda3\envs\tvb-wid\lib\site-packages\ipywidgets\widgets\widget.py:773, in Widget._handle_msg(self, msg)
#     771         if 'buffer_paths' in data:
#     772             _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 773         self.set_state(state)
#     775 # Handle a state request.
#     776 elif method == 'request_state':
#
# File c:\Users\Dell\anaconda3\envs\tvb-wid\lib\site-packages\ipywidgets\widgets\widget.py:650, in Widget.set_state(self, sync_data)
#     645         self._send(msg, buffers=echo_buffers)
#     647 # The order of these context managers is important. Properties must
#     648 # be locked when the hold_trait_notification context manager is
#     649 # released and notifications are fired.
# --> 650 with self._lock_property(**sync_data), self.hold_trait_notifications():
#     651     for name in sync_data:
#     652         if name in self.keys:
#
# File c:\Users\Dell\anaconda3\envs\tvb-wid\lib\contextlib.py:142, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     140 if typ is None:
#     141     try:
# --> 142         next(self.gen)
#     143     except StopIteration:
#     144         return False
#
# File c:\Users\Dell\anaconda3\envs\tvb-wid\lib\site-packages\traitlets\traitlets.py:1510, in HasTraits.hold_trait_notifications(self)
#    1508 for changes in cache.values():
#    1509     for change in changes:
# -> 1510         self.notify_change(change)
#
# File c:\Users\Dell\anaconda3\envs\tvb-wid\lib\site-packages\ipywidgets\widgets\widget.py:701, in Widget.notify_change(self, change)
#     698     if name in self.keys and self._should_send_property(name, getattr(self, name)):
#     699         # Send new state to front-end
#     700         self.send_state(key=name)
# --> 701 super().notify_change(change)
#
# File c:\Users\Dell\anaconda3\envs\tvb-wid\lib\site-packages\traitlets\traitlets.py:1525, in HasTraits.notify_change(self, change)
#    1523 def notify_change(self, change: Bunch) -> None:
#    1524     """Notify observers of a change event"""
# -> 1525     return self._notify_observers(change)
#
# File c:\Users\Dell\anaconda3\envs\tvb-wid\lib\site-packages\traitlets\traitlets.py:1568, in HasTraits._notify_observers(self, event)
#    1565 elif isinstance(c, EventHandler) and c.name is not None:
#    1566     c = getattr(self, c.name)
# -> 1568 c(event)
#
# File c:\users\dell\tvb-widgets\tvbwidgets\ui\spacetime_widget.py:186, in SpaceTimeVisualizerWidget.on_change_slices(self, change)
#     184     material = p3.MeshPhysicalMaterial(color = "red")
#     185     material2 = p3.MeshPhysicalMaterial(color = "blue")
# --> 186     self.graph_slices[i].material = material + material2
#     187 display(self.renderer)
#
# TypeError: unsupported operand type(s) for +: 'MeshPhysicalMaterial' and 'MeshPhysicalMaterial'

# %%
x.create_matplotlib_graphs()
