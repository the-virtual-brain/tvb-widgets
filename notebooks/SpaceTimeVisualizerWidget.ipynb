# %%
from tvb.datatypes.connectivity import Connectivity
from tvbwidgets.ui.spacetime_widget import SpaceTimeVisualizerWidget
conn = Connectivity.from_file() # defaults to connectivy_76.zip
conn.configure()
# Out:
# 19-06-2024 02:47:44 - DEBUG - tvbwidgets - Package is not fully installed
# 19-06-2024 02:47:44 - DEBUG - tvbwidgets - Version read from the internal package.json file
# 19-06-2024 02:47:44 - INFO - tvbwidgets - Version: 2.0.3
# 2024-06-19 14:47:46,316 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.

# %%
x = SpaceTimeVisualizerWidget(conn)
x.display()
# Out:
# c:\Users\Dell\anaconda3\envs\tvb-wid\lib\site-packages\pythreejs\traits.py:257: UserWarning: 64-bit data types not supported for WebGL data, casting to 32-bit.
#   warnings.warn('64-bit data types not supported for WebGL '
# Tab(children=(Output(), Output()), selected_index=0, titles=('', ''))

# %%
x.create_matplotlib_graphs()
