# %%
from tvb.datatypes.connectivity import Connectivity
from tvbwidgets.ui.connectivity_react.connectivity_widget import ConnectivityWidget

conn = Connectivity.from_file()
conn.configure()

w = ConnectivityWidget(conn)
display(w)
# Out:
# 01-06-2026 10:18:17 - INFO - tvbwidgets - Version: 2.3.2
# 2026-06-01 22:18:18,024 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# ConnectivityWidget ready — 76 regions.
